# %% [markdown]
# <a href="https://colab.research.google.com/github/dutrajunior/python_estudos/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/brunamulinari/BasicPythonProjects/main/Base_ficticia/baseficticia.csv', sep = ';')
df
# Out:
#       id              data_aq        produto  quantidade  valor UN      TotaL  \
# 0      0           01/01/2019         toalha           6  R$ 35,00  R$ 210,00
# 1      1           02/01/2019         toalha           6  R$ 35,00  R$ 210,00
# 2      2           03/01/2019         toalha           2  R$ 35,00   R$ 70,00
# 3      3           01/02/2019         toalha           5  R$ 35,00  R$ 175,00
# 4      4           02/02/2019         toalha           9  R$ 35,00  R$ 315,00
# ..   ...                  ...            ...         ...       ...        ...
# 544  544           31/07/2019  quebra_cabeca           9  R$ 19,99  R$ 179,91
# 545  545           01/08/2019  quebra_cabeca           3  R$ 19,99   R$ 59,97
# 546  546           30/07/2019  quebra_cabeca           4  R$ 19,99   R$ 79,96
# 547  547           31/07/2019  quebra_cabeca           1  R$ 19,99   R$ 19,99
# 548  548  2019-03-03 00:00:00  quebra_cabeca           8  R$ 19,99  R$ 159,92
#
#           setor
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(n=6)
# Out:
#    id     data_aq produto  quantidade  valor UN      TotaL       setor
# 0   0  01/01/2019  toalha           6  R$ 35,00  R$ 210,00  Mesa_banho
# 1   1  02/01/2019  toalha           6  R$ 35,00  R$ 210,00          --
# 2   2  03/01/2019  toalha           2  R$ 35,00   R$ 70,00  mesa_banho
# 3   3  01/02/2019  toalha           5  R$ 35,00  R$ 175,00        nada
# 4   4  02/02/2019  toalha           9  R$ 35,00  R$ 315,00  mesa_banho
# 5   5  04/01/2019     NaN           2  R$ 35,00   R$ 70,00  mesa_banho

# %% [markdown]
# Definir valores padrões de dados ausentes/nulos da base de dados como nulos já na importação

# %%
df = pd.read_csv('https://raw.githubusercontent.com/brunamulinari/BasicPythonProjects/main/Base_ficticia/baseficticia.csv', sep = ';', na_values=['--','n/a', 'nada'])

# %%
df.head(n=6)
# Out:
#    id     data_aq produto  quantidade  valor UN      TotaL       setor
# 0   0  01/01/2019  toalha           6  R$ 35,00  R$ 210,00  Mesa_banho
# 1   1  02/01/2019  toalha           6  R$ 35,00  R$ 210,00         NaN
# 2   2  03/01/2019  toalha           2  R$ 35,00   R$ 70,00  mesa_banho
# 3   3  01/02/2019  toalha           5  R$ 35,00  R$ 175,00         NaN
# 4   4  02/02/2019  toalha           9  R$ 35,00  R$ 315,00  mesa_banho
# 5   5  04/01/2019     NaN           2  R$ 35,00   R$ 70,00  mesa_banho

# %%
df.tail(n=5)
# Out:
#       id              data_aq        produto  quantidade  valor UN      TotaL  \
# 544  544           31/07/2019  quebra_cabeca           9  R$ 19,99  R$ 179,91
# 545  545           01/08/2019  quebra_cabeca           3  R$ 19,99   R$ 59,97
# 546  546           30/07/2019  quebra_cabeca           4  R$ 19,99   R$ 79,96
# 547  547           31/07/2019  quebra_cabeca           1  R$ 19,99   R$ 19,99
# 548  548  2019-03-03 00:00:00  quebra_cabeca           8  R$ 19,99  R$ 159,92
#
#           setor
# 544  brinquedos
# 545  brinquedos
# 546  brinquedos
# 547  brinquedos
# 548  Brinquedos

# %% [markdown]
# Total de linhas e colunas

# %%
df.shape
# Out:
# (549, 7)

# %% [markdown]
# Informações gerais sobre os tipos das colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          549 non-null    int64
#  1   data_aq     549 non-null    object
#  2   produto     542 non-null    object
#  3   quantidade  549 non-null    int64
#  4   valor UN    549 non-null    object
#  5   TotaL       549 non-null    object
#  6   setor       535 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 30.1+ KB

# %% [markdown]
# Retornar as colunas

# %%
df.columns
# Out:
# Index(['id', 'data_aq', 'produto', 'quantidade', 'valor UN', 'TotaL', 'setor'], dtype='object')

# %% [markdown]
# Alterar nomes das colunas

# %%
df.columns = ['id', 'data_aq', 'produto', 'quantidade', 'valor_un', 'valor_total', 'setor']

# %%
df.columns
# Out:
# Index(['id', 'data_aq', 'produto', 'quantidade', 'valor_un', 'valor_total',
#        'setor'],
#       dtype='object')

# %% [markdown]
# Avaliar valores nulos em cada coluna

# %%
df.isnull().sum()
# Out:
# id              0
# data_aq         0
# produto         7
# quantidade      0
# valor_un        0
# valor_total     0
# setor          14
# dtype: int64

# %% [markdown]
# Substituir os valores nulos por outro valor definido

# %%
df = df.fillna(value=0)

# %% [markdown]
# Substituir os valores nulos pelo valor anterior

# %%
df = df.fillna(method='ffill')

# %% [markdown]
# Substituir os valores nulos pelo valor do registro posterior

# %%
df = df.fillna(method='bfill')

# %% [markdown]
# Remover registros que contenham valores nulos

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# id             0
# data_aq        0
# produto        0
# quantidade     0
# valor_un       0
# valor_total    0
# setor          0
# dtype: int64

# %%
df.shape
# Out:
# (528, 7)

# %% [markdown]
# Trabalhando com uma coluna

# %%
df['setor']
# Out:
# 0      Mesa_banho
# 2      mesa_banho
# 4      mesa_banho
# 6      mesa_banho
# 7      mesa_banho
#           ...
# 544    brinquedos
# 545    brinquedos
# 546    brinquedos
# 547    brinquedos
# 548    Brinquedos
# Name: setor, Length: 528, dtype: object

# %%
type(df['setor'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Valores únicos da coluna (select distinct no sql)

# %%
df['setor'].unique()
# Out:
# array(['Mesa_banho', 'mesa_banho', 'mesa_Banho', 'perfumaria',
#        'informatica', 'Informatica', 'informaticA', 'brinquedos',
#        'brinquEdos', 'Brinquedos'], dtype=object)

# %% [markdown]
# Função para alterar as strings de uma coluna para minusculo

# %%
def transforma_para_minusculas(x):
   return(str(x).lower())
df['setor'] = df['setor'].apply(func = transforma_para_minusculas)

# %%
df['setor'].unique()
# Out:
# array(['mesa_banho', 'perfumaria', 'informatica', 'brinquedos'],
#       dtype=object)

# %% [markdown]
# Totalizando as quantidades por valores de uma coluna (group by no sql)

# %%
df.setor.value_counts()

# %%
df['setor'].value_counts()
# Out:
# brinquedos     166
# informatica    144
# mesa_banho     141
# perfumaria      77
# Name: setor, dtype: int64

# %% [markdown]
# Totalizando as quantidades por valores de uma coluna e ordenando (group and order by no sql)

# %%
df['setor'].value_counts().sort_values(ascending = True)
# Out:
# perfumaria      77
# mesa_banho     141
# informatica    144
# brinquedos     166
# Name: setor, dtype: int64

# %% [markdown]
# Grafico rápido

# %%
df['setor'].value_counts().plot(kind='bar');

# %% [markdown]
# Usando Map com Lambda ao invés de apply
#
# Substitui os caracteres formados pelo cifrão da moeda reais por nada

# %%
df['valor_total'] = df['valor_total'].map(lambda x: str(x).replace('R$ ', ''))

# %%
df['valor_total'][0]
# Out:
# '210,00'

# %%
df['valor_total'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Padronizar novamente os dados para alterar a virgula para ponto e tranformas os valores para numéricos

# %%
df['valor_total'] = pd.to_numeric(df['valor_total'].map(lambda x: str(x).replace(',', '.')))

# %%
df['valor_total'].dtype
# Out:
# dtype('float64')

# %%
df['valor_total'].sum()
# Out:
# 148230.64

# %%
df.loc[0:3,'id':'valor_un']
# Out:
#    id     data_aq produto  quantidade  valor_un
# 0   0  01/01/2019  toalha           6  R$ 35,00
# 2   2  03/01/2019  toalha           2  R$ 35,00

# %%
df.iloc[0:2,0:5]
# Out:
#    id     data_aq produto  quantidade  valor_un
# 0   0  01/01/2019  toalha           6  R$ 35,00
# 2   2  03/01/2019  toalha           2  R$ 35,00

# %%
df.loc[df['setor'] == 'informatica', 'valor_total']
# Out:
# 229    178.90
# 230    196.79
# 231    107.34
# 232     35.78
# 233    107.34
#         ...
# 372    163.95
# 373    218.60
# 374    491.85
# 375     54.65
# 376    109.30
# Name: valor_total, Length: 144, dtype: float64

# %%
df.loc[df['setor'] == 'informatica', 'valor_total'].sum()
# Out:
# 29542.489999999998

# %% [markdown]
# Dados básicos estatisticos do dataframe

# %%
df.describe()
# Out:
#                id  quantidade  valor_total
# count  528.000000  528.000000   528.000000
# mean   275.229167    6.032197   280.739848
# std    157.431587    3.207100   383.826301
# min      0.000000    1.000000     2.990000
# 25%    137.750000    3.000000    64.950000
# 50%    276.000000    6.000000   142.890000
# 75%    411.250000    9.000000   317.137500
# max    548.000000   11.000000  2310.000000

# %% [markdown]
# Média de valores

# %%
df['valor_total'].mean()
# Out:
# 280.7398484848485

# %% [markdown]
# Média de valores agrupados por Setor

# %%
df.groupby('setor')['valor_total'].mean()
# Out:
# setor
# brinquedos     104.540422
# informatica    205.156181
# mesa_banho     365.638298
# perfumaria     646.486234
# Name: valor_total, dtype: float64

# %%
df.groupby('setor')['valor_total'].median()
# Out:
# setor
# brinquedos      90.93
# informatica    162.48
# mesa_banho     285.00
# perfumaria     210.00
# Name: valor_total, dtype: float64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv', sep = ',')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Criar uma nova coluna calculada com uma função

# %%
def age_analysis(x):
  if x > 60:
    return True
  else:
    return False

# %%
df['AgeAnalysis'] = df['Age'].apply(age_analysis)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  AgeAnalysis
# 0                       0.627   50        1        False
# ...

# %% [markdown]
# Criar nova tabela com base na primeira

# %%
dfDiabeticos = df[df['Outcome']==1]

# %%
dfDiabeticos.shape
# Out:
# (268, 10)

# %%
sum(dfDiabeticos['AgeAnalysis']) #somando os valores booleanos True=1
# Out:
# 7

# %%
bebidas = pd.read_csv('https://gist.githubusercontent.com/aegorenkov/f7f0f8d6e9cc17ca9774572e224e2ad1/raw/9429430ee053bc796d694ed7e88b333a54f3e287/drinks.csv', sep = ',')
bebidas
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
bebidas.shape
# Out:
# (193, 6)

# %%
bebidas.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
bebidas.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
bebidas['continent'].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
bebidas= bebidas.fillna('SI')

# %%
bebidas['continent'].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# SI    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
bebidas[bebidas['continent']=='SI']
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %% [markdown]
# Filtro por letras de string

# %%
bebidas[bebidas['country'].str.startswith('B')]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 11             Bahamas            122              176             51
# 12             Bahrain             42               63              7
# 13          Bangladesh              0                0              0
# 14            Barbados            143              173             36
# 15             Belarus            142              373             42
# 16             Belgium            295               84            212
# 17              Belize            263              114              8
# 18               Benin             34                4             13
# 19              Bhutan             23                0              0
# 20             Bolivia            167               41              8
# 21  Bosnia-Herzegovina             76              173              8
# 22            Botswana            173               35             35
# ...

# %%
bebidas['beer_servings'].max()
# Out:
# 376

# %%
bebidas['beer_servings'].idxmax() #retorna o id do registro com o maximo valor
# Out:
# 117

# %%
bebidas.loc[117:]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 117      Namibia            376                3              1
# 118        Nauru             49                0              8
# 119        Nepal              5                6              0
# 120  Netherlands            251               88            190
# 121  New Zealand            203               79            175
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 118                           1.0        OC
# 119                           0.2        AS
# ...

# %%
bebidas.loc[bebidas['beer_servings'].idxmax()]
# Out:
# country                         Namibia
# beer_servings                       376
# spirit_servings                       3
# wine_servings                         1
# total_litres_of_pure_alcohol        6.8
# continent                            AF
# Name: 117, dtype: object

# %%
bebidas.iloc[bebidas['beer_servings'].idxmax()]
# Out:
# country                         Namibia
# beer_servings                       376
# spirit_servings                       3
# wine_servings                         1
# total_litres_of_pure_alcohol        6.8
# continent                            AF
# Name: 117, dtype: object

# %%
bebidas.groupby('continent').mean().sort_values('beer_servings')
# Out:
# <ipython-input-11-fc5aaef1b049>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bebidas.groupby('continent').mean().sort_values('beer_servings')
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AS             37.045455        60.840909       9.068182
# AF             61.471698        16.339623      16.264151
# OC             89.687500        58.437500      35.625000
# SI            145.434783       165.739130      24.521739
# SA            175.083333       114.750000      62.416667
# EU            193.777778       132.555556     142.222222
#
#            total_litres_of_pure_alcohol
# continent
# AS                             2.170455
# AF                             3.007547
# OC                             3.381250
# SI                             5.995652
# ...

# %% [markdown]
# Ao se criar uma nova tabela a partir da uma original, os indices originais se mantem na nova.

# %%
amerSul = bebidas[bebidas['continent']=='SA']
amerSul
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol continent
# 6                             8.3        SA
# 20                            3.8        SA
# ...

# %%
amerSul['country'].unique()
# Out:
# array(['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador',
#        'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'],
#       dtype=object)

# %% [markdown]
# Criar um novo indice

# %%
amerSul.reset_index(inplace=True)
amerSul
# Out:
#     index    country  beer_servings  spirit_servings  wine_servings  \
# 0       6  Argentina            193               25            221
# 1      20    Bolivia            167               41              8
# 2      23     Brazil            245              145             16
# 3      35      Chile            130              124            172
# 4      37   Colombia            159               76              3
# 5      52    Ecuador            162               74              3
# 6      72     Guyana             93              302              1
# 7     132   Paraguay            213              117             74
# 8     133       Peru            163              160             21
# 9     163   Suriname            128              178              7
# 10    185    Uruguay            115               35            220
# 11    188  Venezuela            333              100              3
#
#     total_litres_of_pure_alcohol continent
# ...

# %%
pessoas = {'country': ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'],
          'population_millions': ['44.49', '11.35', '209.5', '18.73', '49.65', '17.08', '0.77', '6.95', '31.99', '0.57', '3.45', '28.87']}

pessoas = pd.DataFrame(pessoas)
pessoas.head()
# Out:
#      country population_millions
# 0  Argentina               44.49
# 1    Bolivia               11.35
# 2     Brazil               209.5
# 3      Chile               18.73
# 4   Colombia               49.65

# %%
pessoas['population_millions']=pd.to_numeric(pessoas['population_millions'], downcast="float")

# %% [markdown]
# Fazer um merge de dados entre duas tabelas, semelhante ao join do sql, usando a clausula on para definir as colunas da relação de igualdade

# %%
asComplete = pd.merge(amerSul, pessoas, how="inner", on='country')
asComplete.head()
# Out:
#    index    country  beer_servings  spirit_servings  wine_servings  \
# 0      6  Argentina            193               25            221
# 1     20    Bolivia            167               41              8
# 2     23     Brazil            245              145             16
# 3     35      Chile            130              124            172
# 4     37   Colombia            159               76              3
#
#    total_litres_of_pure_alcohol continent  population_millions
# 0                           8.3        SA            44.490002
# 1                           3.8        SA            11.350000
# 2                           7.2        SA           209.500000
# 3                           7.6        SA            18.730000
# 4                           4.2        SA            49.650002

# %% [markdown]
# **Consultas com filtros tipo where de sql**

# %%
asComplete.query('population_millions > 100')
# Out:
#    index country  beer_servings  spirit_servings  wine_servings  \
# 2     23  Brazil            245              145             16
#
#    total_litres_of_pure_alcohol continent  population_millions
# 2                           7.2        SA                209.5

# %%
asComplete.query('country == "Brazil"')
# Out:
#    index country  beer_servings  spirit_servings  wine_servings  \
# 2     23  Brazil            245              145             16
#
#    total_litres_of_pure_alcohol continent population_millions
# 2                           7.2        SA               209.5

# %%
asComplete.query('country != "Brazil" & spirit_servings > 40')

# %%
asComplete.query('beer_servings > 200 | spirit_servings > 70')

# %% [markdown]
# **Renomear Colunas**

# %%
students = {
    "firstname": ["John", "Jane", "Jade"],
    "lastname": ["Doe", "Done", "Do"]
}

df = pd.DataFrame(students)

df.rename(columns={"firstname": "FIRSTNAME", "lastname": "LASTNAME"}, inplace=True)

print(df)
# Out:
#   FIRSTNAME LASTNAME
# 0      John      Doe
# 1      Jane     Done
# 2      Jade       Do

# %%
students = {
    "firstname": ["John", "Jane", "Jade"],
    "lastname": ["Doe", "Done", "Do"]
}

# convert student names into a Dataframe
df = pd.DataFrame(students)
df.columns = ["FIRSTNAME", "SURNAME"]

print(df)
# Out:
#   FIRSTNAME SURNAME
# 0      John     Doe
# 1      Jane    Done
# 2      Jade      Do

# %%
students = {
    "firstname": ["John", "Jane", "Jade"],
    "lastname": ["Doe", "Done", "Do"]
}

# convert student names into a Dataframe
df = pd.DataFrame(students)

df.set_axis(["FIRSTNAME", "SURNAME"], axis="columns")

print(df)
# Out:
#   firstname lastname
# 0      John      Doe
# 1      Jane     Done
# 2      Jade       Do

# %% [markdown]
# **Definir uma coluna como indice do dataframe** - *set_index()*

# %%
students = {
    "firstname": ["John", "Jane", "Jade"],
    "lastname": ["Doe", "Done", "Do"]
}

# convert student names into a Dataframe
df = pd.DataFrame(students)

# setting first name as index column
df.set_index("firstname", inplace = True)

# display
df
# Out:
#           lastname
# firstname
# John           Doe
# Jane          Done
# Jade            Do

# %% [markdown]
# ## Junção de dados

# %% [markdown]
# **append**
#
# *Consta em depreciação*
#
# Anexa um conjunto de dados ao final do dataframe selecionado, tem a opção de manter (ignore_index) os indices originais ou continuar o indice da tabela principal

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']})
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
result = df1.append(df2, ignore_index=True)
result
# Out:
# <ipython-input-105-276070303a24>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = df1.append(df2, ignore_index=True)
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %% [markdown]
# ### Pandas concatenar
#
# Juntar conjuntos registros de conjuntos de dados

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']})
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']})
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %% [markdown]
# Concatena dois dataframes (axis=0)
#
# tem a opção de manter (ignore_index) os indices originais ou continuar o indice da tabela inicial

# %%
result = pd.concat([df1, df2],axis=0, ignore_index=True)
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %% [markdown]
# Juntar colunas de conjuntos de dados (axis=1)

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],})
df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
df2 = pd.DataFrame({'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']})
df2
# Out:
#     C   D
# 0  C4  D4
# 1  C5  D5
# 2  C6  D6
# 3  C7  D7

# %%
result = pd.concat([df1, df2],axis=1)
result
# Out:
#     A   B   C   D
# 0  A0  B0  C4  D4
# 1  A1  B1  C5  D5
# 2  A2  B2  C6  D6
# 3  A3  B3  C7  D7

# %% [markdown]
# **join**

# %%
df_left = pd.DataFrame({"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"])
df_left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df_right = pd.DataFrame({"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"])
df_right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
result = df_left.join(df_right)
result
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
result = df_left.join(df_right, how="outer")
result
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
result = df_left.join(df_right, how="inner")
result
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
df_left = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "key": ["K0", "K1", "K0", "K1"],
    }
)


df_right = pd.DataFrame({"C": ["C0", "C1"], "D": ["D0", "D1"]}, index=["K0", "K1"])

result = df_left.join(df_right, on="key")
result
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K0  C0  D0
# 3  A3  B3  K1  C1  D1
