# %% [markdown]
# <a href="https://colab.research.google.com/github/dutrajunior/python_estudos/blob/main/Gr%C3%A1ficos_de_dispers%C3%A3o_com_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
gorjeta = sn.load_dataset('tips')
gorjeta
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
gorjeta.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
gorjeta.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
gorjeta.shape
# Out:
# (244, 7)

# %%
gorjeta.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
gorjeta.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sn.relplot(data=gorjeta, x="total_bill", y='tip', hue='sex')

# %%
sn.scatterplot(data=gorjeta, x="total_bill", y='tip', hue='day', style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sn.catplot(data=gorjeta, x="day", y='total_bill', kind='swarm')

# %%
sn.lmplot(data=gorjeta, y='tip', hue='smoker', col="time", palette='Set1', scatter_kws={'s':90, 'alpha':0.5}, line_kws={'lw':2})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-8dcbbc01e9b9> in <cell line: 1>()
# ----> 1 sn.lmplot(data=gorjeta, y='tip', hue='smoker', col="time", palette='Set1', scatter_kws={'s':90, 'alpha':0.5}, line_kws={'lw':2})
#
# /usr/local/lib/python3.10/dist-packages/seaborn/regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     622         ax.autoscale_view(scaley=False)
#     623
# --> 624     facets.map_dataframe(update_datalim, x=x, y=y)
#     625
#     626     # Draw the regression plot on each facet
#
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dutrajunior/python_estudos/main/car_price.csv')
df
# Out:
#                       CarName      carbody drivewheel enginelocation fueltype  \
# 0          alfa-romero giulia  convertible        rwd          front      gas
# 1         alfa-romero stelvio  convertible        rwd          front      gas
# 2    alfa-romero Quadrifoglio    hatchback        rwd          front      gas
# 3                 audi 100 ls        sedan        fwd          front      gas
# 4                  audi 100ls        sedan        4wd          front      gas
# ..                        ...          ...        ...            ...      ...
# 205                    bmw x3        sedan        rwd          front      gas
# 206             mitsubishi g4    hatchback        fwd          front      gas
# 207               peugeot 304        sedan        rwd          front   diesel
# 208          peugeot 504 (sw)        wagon        rwd          front      gas
# 209               peugeot 504        wagon        rwd          front   diesel
#
# ...

# %%
df.head()
# Out:
#                     CarName      carbody drivewheel enginelocation fueltype  \
# 0        alfa-romero giulia  convertible        rwd          front      gas
# 1       alfa-romero stelvio  convertible        rwd          front      gas
# 2  alfa-romero Quadrifoglio    hatchback        rwd          front      gas
# 3               audi 100 ls        sedan        fwd          front      gas
# 4                audi 100ls        sedan        4wd          front      gas
#
#   aspiration doornumber cylindernumber enginetype fuelsystem  ...  curbweight  \
# 0        std        two           four       dohc       mpfi  ...        2548
# 1        std        two           four       dohc       mpfi  ...        2548
# 2        std        two            six       ohcv       mpfi  ...        2823
# 3        std       four           four        ohc       mpfi  ...        2337
# 4        std       four           five        ohc       mpfi  ...        2824
#
# ...

# %%
df.tail()
# Out:
#               CarName    carbody drivewheel enginelocation fueltype  \
# 205            bmw x3      sedan        rwd          front      gas
# 206     mitsubishi g4  hatchback        fwd          front      gas
# 207       peugeot 304      sedan        rwd          front   diesel
# 208  peugeot 504 (sw)      wagon        rwd          front      gas
# 209       peugeot 504      wagon        rwd          front   diesel
#
#     aspiration doornumber cylindernumber enginetype fuelsystem  ...  \
# 205        std       four            six        ohc       mpfi  ...
# 206        std        two           four        ohc       2bbl  ...
# 207      turbo       four           four          l        idi  ...
# 208        std       four           four          l       mpfi  ...
# 209      turbo       four           four          l        idi  ...
#
#      curbweight  enginesize  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
df.shape
# Out:
# (210, 25)

# %%
df.dtypes
# Out:
# CarName              object
# carbody              object
# drivewheel           object
# enginelocation       object
# fueltype             object
# aspiration           object
# doornumber           object
# cylindernumber       object
# enginetype           object
# fuelsystem           object
# symboling             int64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginesize            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  210.000000  210.000000  210.000000  210.000000  210.000000
# mean     0.828571   98.947143  174.354286   65.935714   53.768571
# std      1.244757    6.172319   12.457557    2.141794    2.489242
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.800000   64.125000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.500000   66.900000   55.575000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   210.000000  210.000000  210.000000  210.000000        210.000000
# mean   2565.909524  127.266667    3.333905    3.258286         10.224381
# std     522.279331   41.297095    0.270150    0.311277          4.068746
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
ax = sn.scatterplot(x='price', y='horsepower', data=df)
plt.ylim(0, None)
plt.xlim(0, None)
# Out:
# (0.0, 47414.1)

# %%
sn.lmplot(x='price', y='horsepower', data=df, fit_reg=False, hue='fueltype')

# %%
sn.lmplot(x='price', y='horsepower', data=df, fit_reg=True, hue='fueltype')

# %%
sn.catplot(x='fuelsystem', y='price', data=df)

# %%
sn.catplot(x='fuelsystem', y='price', data=df, jitter = False)

# %%
sn.catplot(x='fuelsystem', y='price', data=df, hue = 'fueltype')

# %%
sn.catplot(x='fuelsystem', y='price', hue = 'fueltype', data=df, jitter = False)

# %%
sn.catplot(x='fuelsystem', y='price', hue = 'fueltype', data=df, kind = 'box')

# %%
sn.catplot(x='fuelsystem', y='price', hue = 'fueltype', data=df, kind = 'boxen')

# %%
sn.catplot(x='fuelsystem', y='price', hue = 'fueltype', data=df, kind = 'boxen')
sn.stripplot(x='fuelsystem', y='price', color = 'green', data=df)
# Out:
# <Axes: xlabel='fuelsystem', ylabel='price'>
